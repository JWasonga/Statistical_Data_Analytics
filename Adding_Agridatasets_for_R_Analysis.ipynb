# %% [markdown]
# <a href="https://colab.research.google.com/github/JWasonga/Python-Projects/blob/Applied_Statistics_and_Econometrics-_Portfolio/Adding_Agridatasets_for_R_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install agridatasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.7/122.7 kB 5.0 MB/s eta 0:00:00
# ...

# %%
import agridatasets as agd

# %%
for name in agd.list_datasets():
  agd.load_dataset(name).to_csv(f"{name}.csv", index = False)
